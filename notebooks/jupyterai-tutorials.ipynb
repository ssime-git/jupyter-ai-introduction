# %% [markdown]
# # `jupyter-ai` tutorial
#
# This notebook will introduce you to the main features of the `jupyter-ai` extension.
#
# We will show ythe basic commands to use both `ollama` and `gemini` models.
#
# You can find all the documentation [here](https://jupyter-ai.readthedocs.io/en/latest/users/index.html#prerequisites).

# %% [markdown]
# ## Load the extension

# %%
# Loading the extension
# %load_ext jupyter_ai_magics

# %% [markdown]
# To check the available model that can be used.
#
# We can clearly see gemini models and ollama.

# %%
# Check available AI models
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# gemini
# Requires environment variable: GOOGLE_API_KEY (set)
# * gemini:gemini-1.5-pro
# * gemini:gemini-1.5-flash
# * gemini:gemini-1.0-pro
# * gemini:gemini-1.0-pro-001
# * gemini:gemini-1.0-pro-latest
# * gemini:gemini-1.0-pro-vision-latest
# * gemini:gemini-pro
# * gemini:gemini-pro-vision
#
# gpt4all
# * gpt4all:ggml-gpt4all-j-v1.2-jazzy
# * gpt4all:ggml-gpt4all-j-v1.3-groovy
# * gpt4all:ggml-gpt4all-l13b-snoozy
# * gpt4all:mistral-7b-openorca.Q4_0
# * gpt4all:mistral-7b-instruct-v0.1.Q4_0
# * gpt4all:gpt4all-falcon-q4_0
# * gpt4all:wizardlm-13b-v1.2.Q4_0
# * gpt4all:nous-hermes-llama2-13b.Q4_0
# * gpt4all:gpt4all-13b-snoozy-q4_0
# * gpt4all:mpt-7b-chat-merges-q4_0
# * gpt4all:orca-mini-3b-gguf2-q4_0
# ...

# %% [markdown]
# ## Sending the first prompt
#
# For this first trail, we will use `ollama llama3.2` and `gemini-2.0-flash`. For the latter, you can get a free API key from `google ai studio`. You simply need to have a google account 😉.

# %%
# %%ai ollama:llama3.2
# Hello, simply answer hello boss !
# Out:
# # Hello Boss
# ### Hello Back!
#
# *   *Task Complete*
# *   *Ready for Next Instruction*

# %%
# %%ai gemini:gemini-2.0-flash
# Explain in simple terms what a Python list comprehension is.
# Out:
# A Python list comprehension is a concise way to create a new list based on an existing list or other iterable. It's like a shorthand for a `for` loop combined with an `if` statement (optional) all within square brackets.
#
# **Think of it like this:**
#
# "I want a new list, made up of these things, but only if they meet this condition."
#
# **Example:**
#
# Instead of:
#
# ```python
# numbers = [1, 2, 3, 4, 5]
# squares = []
# for number in numbers:
#   if number % 2 == 0:  # Only even numbers
#     squares.append(number * number)
#
# print(squares) # Output: [4, 16]
# ```
#
# You can do this:
#
# ```python
# numbers = [1, 2, 3, 4, 5]
# squares = [number * number for number in numbers if number % 2 == 0]
#
# print(squares) # Output: [4, 16]
# ```
#
# **Breakdown:**
#
# `[number * number for number in numbers if number % 2 == 0]`
#
# ...

# %% [markdown]
# Just like that, you now have 2 models, one that runs locally and another one from google cloud.
#
# ## Defining the default model

# %%
# Defining the default model to use in the cells
# %config AiMagics.default_language_model = "gemini:gemini-2.0-flash"

# %%
# %%ai
# Explain in simple terms
# the list comprehension operation with Python
# Out:
# A list comprehension in Python is a compact way to create new lists from existing iterables (like lists, tuples, strings, etc.).  It's basically a single line of code that combines a `for` loop and an optional `if` condition to generate a new list.
#
# **Think of it as a recipe:**
#
# "Take these ingredients (the iterable), process them in this way (the expression), but only if they meet this requirement (the condition), and put the results into a new list."
#
# **Key Components:**
#
# 1.  **Expression:** The operation you want to perform on each item in the iterable (e.g., squaring a number, converting to uppercase).  The result of this expression becomes an element in the new list.
# 2.  **Iterable:** The sequence you're looping through (e.g., a list of numbers, a string of characters).
# 3.  **Optional Condition:** A filter that determines whether or not an item from the iterable should be included in the new list.
#
# **Basic Syntax:**
#
# ...

# %% [markdown]
# ## Data Science use case
#
# Let's import some data and see how we can levarage this extension further.

# %%
# %%ai -f code
# write the python code
# to load iris dataset from scikit learn
# into pandas dataframe
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Create a Pandas DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add the target variable (species) to the DataFrame
df['target'] = iris.target

# Add the target names (species names) to the DataFrame
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Print the first few rows of the DataFrame
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %% [markdown]
# It is possible to use previous input, output or even error in a prompt as you can see below

# %%
# %%ai ollama:llama3.2
# As a data Scientist with extensive knowledge
# what are the steps to follow after
# --
# {In[12]}
# Out:
# **Step 1: Data Exploration and Visualization**
# ```python
# import matplotlib.pyplot as plt
#
# # Display summary statistics of the dataset
# print(df.describe())
#
# # Plot a scatter plot to visualize the relationship between features
# plt.figure(figsize=(8,6))
# for species in df['species'].unique():
#     species_df = df[df['species'] == species]
#     plt.scatter(species_df[iris.feature_names], species_df['target'], label=species)
# plt.xlabel(iris.feature_names)
# plt.ylabel('Species')
# plt.title('Iris Dataset Visualization')
# plt.legend()
# plt.show()
# ```
#
# **Step 2: Data Preprocessing**
# ```python
# # Handle missing values (none in this case)
# df = df.dropna()
#
# # Convert categorical variables to numerical variables
# df['species'] = df['species'].cat.codes
#
# # Scale features using StandardScaler or MinMaxScaler
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# df_scaled = scaler.fit_transform(df[iris.feature_names])
#
# ...

# %% [markdown]
# ## Data exploration
#
# Let's one of the sample code provided.

# %%
import matplotlib.pyplot as plt

# Plot a scatter plot to visualize the relationship between features
plt.figure(figsize=(8,6))
for species in df['species'].unique():
    species_df = df[df['species'] == species]
    plt.scatter(species_df[iris.feature_names], species_df['target'], label=species)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 7
#       5 for species in df['species'].unique():
#       6     species_df = df[df['species'] == species]
# ----> 7     plt.scatter(species_df[iris.feature_names], species_df['target'], label=species)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
# ...

# %% [markdown]
# Lets' now imagine that we want to debug the problematic code.

# %%
# %%ai
# When running the code
# --
# {In[29]}
# --
# i have the error ValueError: x and y must be the same size
# what sjould i do ?
# Out:
# ```markdown
# **Error:**
#
# `ValueError: x and y must be the same size`
#
# **Explanation:**
#
# This error arises because the `plt.scatter()` function requires the `x` and `y` arguments to have the same number of elements. In your code, you're passing `species_df[iris.feature_names]` as `x` and `species_df['target']` as `y`.
#
# *   `species_df[iris.feature_names]` is a DataFrame containing potentially multiple feature columns (e.g., 'sepal length (cm)', 'sepal width (cm)', etc.).  It has a shape of (number of rows for that species, number of features).
# *   `species_df['target']` is a Series containing the target values (species labels) for the rows corresponding to that species. It has a shape of (number of rows for that species,).
#
# The number of elements in `x` (which is essentially the number of rows times the number of features) is almost certainly different from the number of elements in `y` (which is the number of rows).  That's why you're getting the `ValueError`.
#
# ...

# %%
# Corrected Scatter Plots - Feature vs. Target (for each feature)
plt.figure(figsize=(16, 10))  # Adjust figure size for multiple subplots

for i, feature in enumerate(iris.feature_names):
    plt.subplot(2, 2, i + 1)  # Create subplots in a 2x2 grid
    for species in df['species'].unique():
        species_df = df[df['species'] == species]
        plt.scatter(species_df[feature], species_df['target'], label=species)
    plt.xlabel(feature)
    plt.ylabel('Species (Target)')
    plt.title(f'{feature} vs. Species')  # More informative title
    plt.legend()

plt.tight_layout()  # Adjust subplot parameters for a tight layout
plt.show()

# %%
# %%ai gemini:gemini-2.5-flash-preview-04-17
# Not sure that this visualization provide any info
# what do you think ? May be box plot are better suited
# What do you think ?
# --
# {In[31]}
# Out:
# ```markdown
# That's an excellent point and a very insightful question! You are absolutely right that **box plots are often a better and more intuitive way to visualize the distribution of a numerical feature across different categories (like species)** compared to the scatter plot of feature vs. target (numerical).
#
# Let's break down why:
#
# 1.  **What the Scatter Plot (Feature vs. Target) Shows:**
#     *   As discussed, it plots each data point's feature value against its numerical target label (0, 1, 2).
#     *   It shows the *exact range* of feature values for each species.
#     *   It helps visualize if there are clear boundaries or overlaps in feature values between species *at those specific target levels*.
#     *   *Limitation:* The y-axis (target) is categorical, but we're plotting it numerically. This can make the vertical spread look like variance, but it's just points stacked at 0, 1, or 2. It's not showing a continuous relationship.
#
# ...

# %%
import seaborn as sns
# Box Plots - Distribution of Each Feature Grouped by Species
plt.figure(figsize=(16, 10)) # Adjust figure size

for i, feature in enumerate(iris.feature_names):
    plt.subplot(2, 2, i + 1) # Create subplots
    sns.boxplot(x='species', y=feature, data=df) # Use seaborn boxplot
    plt.title(f'{feature} by Species') # Title reflecting the feature
    plt.xlabel('Species')
    plt.ylabel(feature)

plt.tight_layout() # Adjust layout
plt.show()
